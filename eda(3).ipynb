# %% [markdown]
# **Сразу извиняюсь за кривое написание)**

# %% [markdown]
# # Context

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# %%
data_eda = pd.read_csv('C:\\train.csv')
sns.set(context = 'notebook')

# %% [markdown]
# # Data quality assessment

# %%
data_eda.corr().unstack().abs().sort_values(ascending = False)[7:].drop_duplicates()
# Out:
# Fare         Pclass         0.417354
# Survived     Pclass         0.289723
# Age          Pclass         0.259109
# Parch        SibSp          0.213126
# Fare         Survived       0.187534
# Parch        Age            0.125535
# SibSp        Age            0.112459
# Fare         Age            0.109164
# Age          Survived       0.103895
# Fare         Parch          0.061443
# SibSp        Fare           0.059358
#              Pclass         0.051436
# Pclass       Parch          0.041848
# Survived     Parch          0.023352
# SibSp        Survived       0.007587
# PassengerId  Age            0.002654
#              Survived       0.001956
# Fare         PassengerId    0.001036
# PassengerId  SibSp          0.001000
# Pclass       PassengerId    0.000893
# Parch        PassengerId    0.000411
# dtype: float64

# %%
data_eda.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 12 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   PassengerId  100000 non-null  int64
#  1   Survived     100000 non-null  int64
#  2   Pclass       100000 non-null  int64
#  3   Name         100000 non-null  object
#  4   Sex          100000 non-null  object
#  5   Age          96708 non-null   float64
#  6   SibSp        100000 non-null  int64
#  7   Parch        100000 non-null  int64
#  8   Ticket       95377 non-null   object
#  9   Fare         99866 non-null   float64
#  10  Cabin        32134 non-null   object
#  11  Embarked     99750 non-null   object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 9.2+ MB

# %%
data_eda
# Out:
#        PassengerId  Survived  Pclass                Name     Sex    Age  \
# 0                0         1       1    Oconnor, Frankie    male    NaN
# 1                1         0       3         Bryan, Drew    male    NaN
# 2                2         0       3      Owens, Kenneth    male   0.33
# 3                3         0       3       Kramer, James    male  19.00
# 4                4         1       3       Bond, Michael    male  25.00
# ...            ...       ...     ...                 ...     ...    ...
# 99995        99995         1       2         Bell, Adele  female  62.00
# 99996        99996         0       2       Brown, Herman    male  66.00
# 99997        99997         0       3  Childress, Charles    male  37.00
# 99998        99998         0       3    Caughlin, Thomas    male  51.00
# 99999        99999         0       3       Enciso, Tyler    male  55.00
#
#        SibSp  Parch     Ticket   Fare   Cabin Embarked
# 0          2      0     209245  27.14  C12239        S
# 1          0      0      27323  13.35     NaN        S
# 2          1      2  CA 457703  71.29     NaN        S
# 3          0      0   A. 10866  13.04     NaN        S
# 4          0      0     427635   7.76     NaN        S
# ...      ...    ...        ...    ...     ...      ...
# 99995      0      0   PC 15008  14.86  D17243        C
# 99996      0      0      13273  11.15     NaN        S
# 99997      0      0        NaN   9.95     NaN        S
# 99998      0      1     458654  30.92     NaN        S
# 99999      0      0     458074  13.96     NaN        S
#
# [100000 rows x 12 columns]

# %% [markdown]
# # Data exploration

# %%
sns.heatmap(data_eda.isnull(), yticklabels = False, cbar = False, cmap='viridis')
# Out:
# <AxesSubplot:>

# %%
def d(x):
    if x != 0:
        return str(x)[0]
    else:
        return np.nan
data_eda['first_l_cabin'] = data_eda['Cabin'].apply(d)
def d(x):
    if not str(x).split()[0].isdigit():
            if len(str(x).split('. ')) == 2 and len(str(x).split('.')) == 2 and len(str(x).split(' ')) == 2 and len(str(x).split('/')) == 1:
                return str(x).split('. ')[0]
            elif len(str(x).split('.')) == 2 and len(str(x).split('. ')) == 1 and len(str(x).split(' ')) == 1 and len(str(x).split('/')) == 1:
                return str(x).split('.')[0]
            elif len(str(x).split(' ')) == 2 and len(str(x).split('. ')) == 1 and len(str(x).split('.')) == 1 and len(str(x).split('/')) == 1:
                return str(x).split(' ')[0]
            elif len(str(x).split('/')) >= 2 and len(str(x).split('. ')) == 1 and len(str(x).split('.')) == 1:
                return str(x).split('/')[0]
    else:
        return np.nan
data_eda['first_l_ticket'] = data_eda['Ticket'].apply(d)
def d(x):
    if x != 0:
        return str(x)[1:]
    else:
        return np.nan
data_eda['num_of_cabin'] = data_eda['Cabin'].apply(d)
def d(x):
    if x != 0:
        return str(x).split(', ')[0]
    else:
        return np.nan
data_eda['first_name'] = data_eda['Name'].apply(d)
def d(x):
    if x != 0:
        return str(x).split(', ')[1]
    else:
        return np.nan
data_eda['last_name'] = data_eda['Name'].apply(d)
data_eda['family_size'] = data_eda['SibSp'] + data_eda['Parch']

# %%
data_eda['first_l_ticket'].value_counts()
# Out:
# PC       6375
# A        5147
# SC       2211
# STON     1512
# CA        772
# PP        622
# SOTON     547
# C         220
# WE        175
# P         149
# SCO       101
# AQ         73
# LP         56
# Fa         54
# SW         38
# SO         34
# W          28
# A4         19
# Name: first_l_ticket, dtype: int64

# %%
data_eda['first_l_ticket'].drop_duplicates()
# Out:
# 0         NaN
# 2          CA
# 3           A
# 16       None
# 19         PC
# 45         SC
# 197      STON
# 236         C
# 276        AQ
# 301        WE
# 343        PP
# 438        Fa
# 586         P
# 907     SOTON
# 1050       SW
# 1299        W
# 1920       SO
# 1927      SCO
# 2975       LP
# 5560       A4
# Name: first_l_ticket, dtype: object

# %%
plt.figure(figsize=(12,6))
plt.title('возраст')
sns.distplot(a=data_eda['Age'], kde=True)
# Out:
# C:\Users\Alexander\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:title={'center':'возраст'}, xlabel='Age', ylabel='Density'>

# %%
plt.figure(figsize=(5,3))
plt.title('Выживание (кол-во)')
sns.distplot(a=data_eda['Survived'], kde=False)
# Out:
# C:\Users\Alexander\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:title={'center':'Выживание (кол-во)'}, xlabel='Survived'>

# %%
sns.kdeplot(data_eda['Fare'])
plt.title('Цена билета')
# Out:
# Text(0.5, 1.0, 'Цена билета')

# %%
sns.distplot(a=data_eda['Pclass'], kde=False)
plt.title('Класс')
# Out:
# C:\Users\Alexander\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Text(0.5, 1.0, 'Класс')

# %%
sns.distplot(a=data_eda['SibSp'], kde=False)
plt.title('кол-во братьев и сестёр')
# Out:
# Text(0.5, 1.0, 'кол-во братьев и сестёр')

# %%
sns.set(context = 'poster')
plt.title('кол-во родителей и детей')
sns.distplot(a=data_eda['Parch'], kde=True, color = 'red')
# Out:
# <AxesSubplot:title={'center':'кол-во родителей и детей'}, xlabel='Parch', ylabel='Density'>

# %%
sns.set(context = 'notebook')
sns.distplot(a=data_eda.loc[data_eda['Survived'] == 1, 'Age'], label = 'Surv.')
sns.distplot(a=data_eda.loc[data_eda['Survived'] == 0, 'Age'], label = 'Not Surv.', color = 'red')
plt.title('возраст выживших и умерших')
# Out:
# C:\Users\Alexander\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Alexander\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Text(0.5, 1.0, 'возраст выживших и умерших')

# %%
pd.crosstab([data_eda.Sex,data_eda.Survived],data_eda.Pclass,margins=True).style.background_gradient(cmap='summer_r')
# Out:
# <style  type="text/css" >
# #T_b6375_row0_col0,#T_b6375_row3_col1,#T_b6375_row3_col2,#T_b6375_row3_col3{
#             background-color:  #ffff66;
#             color:  #000000;
#         }#T_b6375_row0_col1{
#             background-color:  #fdfe66;
#             color:  #000000;
#         }#T_b6375_row0_col2{
#             background-color:  #eff766;
#             color:  #000000;
#         }#T_b6375_row0_col3{
#             background-color:  #fcfe66;
#             color:  #000000;
#         }#T_b6375_row1_col0{
#             background-color:  #acd666;
#             color:  #000000;
#         }#T_b6375_row1_col1{
#             background-color:  #aad466;
#             color:  #000000;
#         }#T_b6375_row1_col2{
#             background-color:  #e4f266;
#             color:  #000000;
#         }#T_b6375_row1_col3{
#             background-color:  #c7e366;
#             color:  #000000;
#         }#T_b6375_row2_col0{
#             background-color:  #cde666;
#             color:  #000000;
#         }#T_b6375_row2_col1{
#             background-color:  #bbdd66;
#             color:  #000000;
#         }#T_b6375_row2_col2{
#             background-color:  #68b366;
#             color:  #000000;
#         }#T_b6375_row2_col3{
#             background-color:  #a0d066;
#             color:  #000000;
#         }#T_b6375_row3_col0{
#             background-color:  #f1f866;
#             color:  #000000;
#         }#T_b6375_row4_col0,#T_b6375_row4_col1,#T_b6375_row4_col2,#T_b6375_row4_col3{
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }</style><table id="T_b6375_" ><thead>    <tr>        <th class="blank" ></th>        <th class="index_name level0" >Pclass</th>        <th class="col_heading level0 col0" >1</th>        <th class="col_heading level0 col1" >2</th>        <th class="col_heading level0 col2" >3</th>        <th class="col_heading level0 col3" >All</th>    </tr>    <tr>        <th class="index_name level0" >Sex</th>        <th class="index_name level1" >Survived</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_b6375_level0_row0" class="row_heading level0 row0" rowspan="2">female</th>
#                         <th id="T_b6375_level1_row0" class="row_heading level1 row0" >0</th>
#                         <td id="T_b6375_row0_col0" class="data row0 col0" >3727</td>
#                         <td id="T_b6375_row0_col1" class="data row0 col1" >3530</td>
#                         <td id="T_b6375_row0_col2" class="data row0 col2" >5403</td>
#                         <td id="T_b6375_row0_col3" class="data row0 col3" >12660</td>
#             </tr>
#             <tr>
#                                 <th id="T_b6375_level1_row1" class="row_heading level1 row1" >1</th>
#                         <td id="T_b6375_row1_col0" class="data row1 col0" >12357</td>
#                         <td id="T_b6375_row1_col1" class="data row1 col1" >11753</td>
#                         <td id="T_b6375_row1_col2" class="data row1 col2" >7116</td>
#                         <td id="T_b6375_row1_col3" class="data row1 col3" >31226</td>
#             </tr>
#             <tr>
#                         <th id="T_b6375_level0_row2" class="row_heading level0 row2" rowspan="2">male</th>
#                         <th id="T_b6375_level1_row2" class="row_heading level1 row2" >0</th>
#                         <td id="T_b6375_row2_col0" class="data row2 col0" >9012</td>
#                         <td id="T_b6375_row2_col1" class="data row2 col1" >10092</td>
#                         <td id="T_b6375_row2_col2" class="data row2 col2" >25462</td>
#                         <td id="T_b6375_row2_col3" class="data row2 col3" >44566</td>
#             </tr>
#             <tr>
#                                 <th id="T_b6375_level1_row3" class="row_heading level1 row3" >1</th>
#                         <td id="T_b6375_row3_col0" class="data row3 col0" >5219</td>
#                         <td id="T_b6375_row3_col1" class="data row3 col1" >3304</td>
#                         <td id="T_b6375_row3_col2" class="data row3 col2" >3025</td>
#                         <td id="T_b6375_row3_col3" class="data row3 col3" >11548</td>
#             </tr>
#             <tr>
#                         <th id="T_b6375_level0_row4" class="row_heading level0 row4" >All</th>
#                         <th id="T_b6375_level1_row4" class="row_heading level1 row4" ></th>
#                         <td id="T_b6375_row4_col0" class="data row4 col0" >30315</td>
#                         <td id="T_b6375_row4_col1" class="data row4 col1" >28679</td>
#                         <td id="T_b6375_row4_col2" class="data row4 col2" >41006</td>
#                         <td id="T_b6375_row4_col3" class="data row4 col3" >100000</td>
#             </tr>
#     </tbody></table>

# %%
f,ax=plt.subplots(1,2,figsize=(20,20))
data_eda[data_eda['Survived']==0].Age.plot.hist(ax=ax[0],bins=20,edgecolor='black',color='red')
ax[0].set_title('Survived = 0')
x1=list(range(0,85,5))
ax[0].set_xticks(x1)
data_eda[data_eda['Survived']==1].Age.plot.hist(ax=ax[1],bins=20,edgecolor='black',color='green')
x2=list(range(0,85,5))
ax[1].set_xticks(x2)
ax[1].set_title('Survived = 1')
plt.show()

# %%
def d(x):
    if x == 'male':
        return 1
    elif x == 'female':
        return 0
data_eda['Sex_int'] = data_eda['Sex'].apply(d)

# %%
data_eda
# Out:
#        PassengerId  Survived  Pclass                Name     Sex    Age  \
# 0                0         1       1    Oconnor, Frankie    male    NaN
# 1                1         0       3         Bryan, Drew    male    NaN
# 2                2         0       3      Owens, Kenneth    male   0.33
# 3                3         0       3       Kramer, James    male  19.00
# 4                4         1       3       Bond, Michael    male  25.00
# ...            ...       ...     ...                 ...     ...    ...
# 99995        99995         1       2         Bell, Adele  female  62.00
# 99996        99996         0       2       Brown, Herman    male  66.00
# 99997        99997         0       3  Childress, Charles    male  37.00
# 99998        99998         0       3    Caughlin, Thomas    male  51.00
# 99999        99999         0       3       Enciso, Tyler    male  55.00
#
#        SibSp  Parch     Ticket   Fare   Cabin Embarked first_l_cabin  \
# 0          2      0     209245  27.14  C12239        S             C
# 1          0      0      27323  13.35     NaN        S             n
# 2          1      2  CA 457703  71.29     NaN        S             n
# 3          0      0   A. 10866  13.04     NaN        S             n
# 4          0      0     427635   7.76     NaN        S             n
# ...      ...    ...        ...    ...     ...      ...           ...
# 99995      0      0   PC 15008  14.86  D17243        C             D
# 99996      0      0      13273  11.15     NaN        S             n
# 99997      0      0        NaN   9.95     NaN        S             n
# 99998      0      1     458654  30.92     NaN        S             n
# 99999      0      0     458074  13.96     NaN        S             n
#
#       first_l_ticket num_of_cabin first_name last_name  family_size  Sex_int
# 0                NaN        12239    Oconnor   Frankie            2        1
# 1                NaN           an      Bryan      Drew            0        1
# 2                 CA           an      Owens   Kenneth            3        1
# 3                  A           an     Kramer     James            0        1
# 4                NaN           an       Bond   Michael            0        1
# ...              ...          ...        ...       ...          ...      ...
# 99995             PC        17243       Bell     Adele            0        0
# 99996            NaN           an      Brown    Herman            0        1
# 99997           None           an  Childress   Charles            0        1
# 99998            NaN           an   Caughlin    Thomas            1        1
# 99999            NaN           an     Enciso     Tyler            0        1
#
# [100000 rows x 19 columns]

# %%
plt.title('корреляция')
sns.heatmap(data_eda.corr())
# Out:
# <AxesSubplot:title={'center':'корреляция'}>

# %%
sns.catplot('Survived', data=data_eda, kind = 'count')

# %%
#выживание по полам
sns.catplot('Sex', data=data_eda, hue="Survived", kind = 'count')
plt.title('выживание по полам')
# Out:
# C:\Users\Alexander\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'выживание по полам')

# %%
sns.catplot('Pclass', data=data_eda, hue="Survived", kind = 'count')
plt.title('Выживание по классам')
# Out:
# C:\Users\Alexander\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'Выживание по классам')

# %%
sns.catplot('Pclass', data=data_eda, hue='Sex', kind = 'count')
plt.title('Распределение полов по классам')
# Out:
# C:\Users\Alexander\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'Распределение полов по классам')

# %%
sns.catplot('SibSp', data=data_eda, hue='Survived', kind='count')
plt.title('Распределение выживших и не выживших по SibSp')
# Out:
# C:\Users\Alexander\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'Распределение выживших и не выживших по SibSp ')

# %%
sns.catplot('Parch', data=data_eda, hue='Survived', kind='count')
plt.title('Распределение выживших и не выживших по количеству родствеников')
# Out:
# C:\Users\Alexander\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'Распределение выживших и не выживших по количеству родствеников')

# %%
sns.catplot('family_size', data=data_eda, hue='Survived', kind='count')
plt.title('Распределение выживших и не выживших по family_size')
# Out:
# C:\Users\Alexander\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'Распределение выживших и не выживших по family_size')

# %%
sns.catplot('first_l_ticket', data=data_eda, hue='Survived', kind='count')
plt.title('Распределение выживших и не выживших по буквам в билете')
plt.figure(figsize=(2000, 2000))
# Out:
# C:\Users\Alexander\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
f,ax=plt.subplots(1,2,figsize=(20,8))
sns.barplot('SibSp','Survived', data=data_eda,ax=ax[0])
ax[0].set_title('SipSp vs Survived in BarPlot')
sns.factorplot('SibSp','Survived', data=data_eda,ax=ax[1])
ax[1].set_title('SibSp vs Survived in FactorPlot')
plt.close(2)
# Out:
# C:\Users\Alexander\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\Alexander\anaconda3\lib\site-packages\seaborn\categorical.py:3714: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# C:\Users\Alexander\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\Alexander\anaconda3\lib\site-packages\seaborn\categorical.py:3772: UserWarning: catplot is a figure-level function and does not accept target axes. You may wish to try pointplot
#   warnings.warn(msg, UserWarning)

# %%
data_eda['bool_Parch'] = data_eda['Parch'] > 0
sns.catplot('bool_Parch', data=data_eda.loc[data_eda['Sex'] == 'female'], hue = 'Survived', kind='count')
plt.title('Распределение выживших и не выживших по наличию в семье родственников')
# Out:
# C:\Users\Alexander\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'Распределение выживших и не выживших по наличию в семье родственников')

# %%
f,ax=plt.subplots(1,2,figsize=(18,8))
sns.violinplot('Pclass','Age',hue='Survived',data=data_eda,split=True,ax=ax[0])
ax[0].set_title('PClass and Age vs Survived')
ax[0].set_yticks(range(0,110,10))
sns.violinplot("Sex","Age", hue="Survived", data=data_eda,split=True,ax=ax[1])
ax[1].set_title('Sex and Age vs Survived')
ax[1].set_yticks(range(0,110,10))
plt.show()
# Out:
# C:\Users\Alexander\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\Alexander\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
pd.crosstab(data_eda.SibSp,data_eda.Pclass).style.background_gradient('summer_r')
# Out:
# <style  type="text/css" >
# #T_03b03_row0_col0,#T_03b03_row0_col1,#T_03b03_row0_col2{
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }#T_03b03_row1_col0{
#             background-color:  #8dc666;
#             color:  #000000;
#         }#T_03b03_row1_col1{
#             background-color:  #cee666;
#             color:  #000000;
#         }#T_03b03_row1_col2{
#             background-color:  #c9e466;
#             color:  #000000;
#         }#T_03b03_row2_col0{
#             background-color:  #eef666;
#             color:  #000000;
#         }#T_03b03_row2_col1{
#             background-color:  #f1f866;
#             color:  #000000;
#         }#T_03b03_row2_col2{
#             background-color:  #f8fc66;
#             color:  #000000;
#         }#T_03b03_row3_col0,#T_03b03_row3_col2{
#             background-color:  #f9fc66;
#             color:  #000000;
#         }#T_03b03_row3_col1{
#             background-color:  #fdfe66;
#             color:  #000000;
#         }#T_03b03_row4_col0{
#             background-color:  #fefe66;
#             color:  #000000;
#         }#T_03b03_row4_col1{
#             background-color:  #fafc66;
#             color:  #000000;
#         }#T_03b03_row4_col2{
#             background-color:  #fcfe66;
#             color:  #000000;
#         }#T_03b03_row5_col0,#T_03b03_row5_col1,#T_03b03_row5_col2,#T_03b03_row6_col0,#T_03b03_row6_col1,#T_03b03_row6_col2{
#             background-color:  #ffff66;
#             color:  #000000;
#         }</style><table id="T_03b03_" ><thead>    <tr>        <th class="index_name level0" >Pclass</th>        <th class="col_heading level0 col0" >1</th>        <th class="col_heading level0 col1" >2</th>        <th class="col_heading level0 col2" >3</th>    </tr>    <tr>        <th class="index_name level0" >SibSp</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_03b03_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_03b03_row0_col0" class="data row0 col0" >19483</td>
#                         <td id="T_03b03_row0_col1" class="data row0 col1" >22125</td>
#                         <td id="T_03b03_row0_col2" class="data row0 col2" >31700</td>
#             </tr>
#             <tr>
#                         <th id="T_03b03_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_03b03_row1_col0" class="data row1 col0" >8714</td>
#                         <td id="T_03b03_row1_col1" class="data row1 col1" >4283</td>
#                         <td id="T_03b03_row1_col2" class="data row1 col2" >6761</td>
#             </tr>
#             <tr>
#                         <th id="T_03b03_level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_03b03_row2_col0" class="data row2 col0" >1368</td>
#                         <td id="T_03b03_row2_col1" class="data row2 col1" >1329</td>
#                         <td id="T_03b03_row2_col2" class="data row2 col2" >1006</td>
#             </tr>
#             <tr>
#                         <th id="T_03b03_level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_03b03_row3_col0" class="data row3 col0" >525</td>
#                         <td id="T_03b03_row3_col1" class="data row3 col1" >293</td>
#                         <td id="T_03b03_row3_col2" class="data row3 col2" >817</td>
#             </tr>
#             <tr>
#                         <th id="T_03b03_level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_03b03_row4_col0" class="data row4 col0" >154</td>
#                         <td id="T_03b03_row4_col1" class="data row4 col1" >483</td>
#                         <td id="T_03b03_row4_col2" class="data row4 col2" >531</td>
#             </tr>
#             <tr>
#                         <th id="T_03b03_level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_03b03_row5_col0" class="data row5 col0" >24</td>
#                         <td id="T_03b03_row5_col1" class="data row5 col1" >40</td>
#                         <td id="T_03b03_row5_col2" class="data row5 col2" >68</td>
#             </tr>
#             <tr>
#                         <th id="T_03b03_level0_row6" class="row_heading level0 row6" >8</th>
#                         <td id="T_03b03_row6_col0" class="data row6 col0" >47</td>
#                         <td id="T_03b03_row6_col1" class="data row6 col1" >126</td>
#                         <td id="T_03b03_row6_col2" class="data row6 col2" >123</td>
#             </tr>
#     </tbody></table>

# %%
pd.crosstab(data_eda.Parch,data_eda.Pclass).style.background_gradient('summer_r')
# Out:
# <style  type="text/css" >
# #T_ddc24_row0_col0,#T_ddc24_row0_col1,#T_ddc24_row0_col2{
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }#T_ddc24_row1_col0{
#             background-color:  #ddee66;
#             color:  #000000;
#         }#T_ddc24_row1_col1{
#             background-color:  #b4da66;
#             color:  #000000;
#         }#T_ddc24_row1_col2{
#             background-color:  #dfef66;
#             color:  #000000;
#         }#T_ddc24_row2_col0{
#             background-color:  #cbe566;
#             color:  #000000;
#         }#T_ddc24_row2_col1{
#             background-color:  #e6f266;
#             color:  #000000;
#         }#T_ddc24_row2_col2{
#             background-color:  #daec66;
#             color:  #000000;
#         }#T_ddc24_row3_col0{
#             background-color:  #fafc66;
#             color:  #000000;
#         }#T_ddc24_row3_col1,#T_ddc24_row3_col2,#T_ddc24_row4_col0,#T_ddc24_row4_col2{
#             background-color:  #fefe66;
#             color:  #000000;
#         }#T_ddc24_row4_col1,#T_ddc24_row5_col0,#T_ddc24_row5_col1,#T_ddc24_row5_col2,#T_ddc24_row6_col0,#T_ddc24_row6_col1,#T_ddc24_row6_col2,#T_ddc24_row7_col0,#T_ddc24_row7_col1,#T_ddc24_row7_col2{
#             background-color:  #ffff66;
#             color:  #000000;
#         }</style><table id="T_ddc24_" ><thead>    <tr>        <th class="index_name level0" >Pclass</th>        <th class="col_heading level0 col0" >1</th>        <th class="col_heading level0 col1" >2</th>        <th class="col_heading level0 col2" >3</th>    </tr>    <tr>        <th class="index_name level0" >Parch</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_ddc24_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_ddc24_row0_col0" class="data row0 col0" >21888</td>
#                         <td id="T_ddc24_row0_col1" class="data row0 col1" >20166</td>
#                         <td id="T_ddc24_row0_col2" class="data row0 col2" >31486</td>
#             </tr>
#             <tr>
#                         <th id="T_ddc24_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_ddc24_row1_col0" class="data row1 col0" >3001</td>
#                         <td id="T_ddc24_row1_col1" class="data row1 col1" >5965</td>
#                         <td id="T_ddc24_row1_col2" class="data row1 col2" >4030</td>
#             </tr>
#             <tr>
#                         <th id="T_ddc24_level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_ddc24_row2_col0" class="data row2 col0" >4537</td>
#                         <td id="T_ddc24_row2_col1" class="data row2 col1" >2042</td>
#                         <td id="T_ddc24_row2_col2" class="data row2 col2" >4657</td>
#             </tr>
#             <tr>
#                         <th id="T_ddc24_level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_ddc24_row3_col0" class="data row3 col0" >519</td>
#                         <td id="T_ddc24_row3_col1" class="data row3 col1" >177</td>
#                         <td id="T_ddc24_row3_col2" class="data row3 col2" >287</td>
#             </tr>
#             <tr>
#                         <th id="T_ddc24_level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_ddc24_row4_col0" class="data row4 col0" >154</td>
#                         <td id="T_ddc24_row4_col1" class="data row4 col1" >68</td>
#                         <td id="T_ddc24_row4_col2" class="data row4 col2" >224</td>
#             </tr>
#             <tr>
#                         <th id="T_ddc24_level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_ddc24_row5_col0" class="data row5 col0" >109</td>
#                         <td id="T_ddc24_row5_col1" class="data row5 col1" >117</td>
#                         <td id="T_ddc24_row5_col2" class="data row5 col2" >105</td>
#             </tr>
#             <tr>
#                         <th id="T_ddc24_level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_ddc24_row6_col0" class="data row6 col0" >26</td>
#                         <td id="T_ddc24_row6_col1" class="data row6 col1" >54</td>
#                         <td id="T_ddc24_row6_col2" class="data row6 col2" >124</td>
#             </tr>
#             <tr>
#                         <th id="T_ddc24_level0_row7" class="row_heading level0 row7" >9</th>
#                         <td id="T_ddc24_row7_col0" class="data row7 col0" >81</td>
#                         <td id="T_ddc24_row7_col1" class="data row7 col1" >90</td>
#                         <td id="T_ddc24_row7_col2" class="data row7 col2" >93</td>
#             </tr>
#     </tbody></table>

# %%
data_eda['first_l_cabin'].value_counts()
# Out:
# n    67866
# C    11825
# B     7439
# A     6307
# D     3637
# E     1749
# F      663
# G      482
# T       32
# Name: first_l_cabin, dtype: int64

# %%
data_eda['group_age'] = pd.qcut(data_eda['Age'], 5)
sns.catplot(col = 'Sex', x='Survived', data=data_eda, hue='group_age', kind='count')
plt.title('Распределение выживших и не выживших по полу и группе возраста')
# Out:
# Text(0.5, 1.0, 'Распределение выживших и не выживших по полу и группе возраста')

# %%
sns.catplot('first_l_cabin', data=data_eda, hue = 'Survived', kind='count')
plt.title('Распределение выживших и не выживших по первой букве кабины')
# Out:
# C:\Users\Alexander\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'Распределение выживших и не выживших по первой букве кабины')

# %%
data_eda['first_l_cabin'].value_counts()
# Out:
# n    67866
# C    11825
# B     7439
# A     6307
# D     3637
# E     1749
# F      663
# G      482
# T       32
# Name: first_l_cabin, dtype: int64

# %%
data_eda['Embarked'].value_counts()
# Out:
# S    72139
# C    22187
# Q     5424
# Name: Embarked, dtype: int64

# %%
plt.title('распределение по портам')
sns.kdeplot(data_eda['Survived'], hue = data_eda['Embarked'])
# Out:
# <AxesSubplot:title={'center':'распределение по портам'}, xlabel='Survived', ylabel='Density'>

# %%
plt.title('распределение по типам билета')
sns.kdeplot(data_eda['Survived'], hue = data_eda['first_l_ticket'])
# Out:
# <AxesSubplot:title={'center':'распределение по типам билета'}, xlabel='Survived', ylabel='Density'>

# %%
plt.title('распределение с детьми и без')
sns.distplot(data_eda.loc[data_eda['Parch'] >= 1, 'Survived'], kde = False)
sns.distplot(data_eda.loc[data_eda['Parch'] == 0, 'Survived'], kde = False)
# Out:
# C:\Users\Alexander\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Alexander\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:title={'center':'распределение с детьми и без'}, xlabel='Survived'>

# %%
plt.title('Распределение цены билета больше 100 по группе возраста')
sns.barplot('group_age','Fare', data=data_eda[data_eda['Fare']>100], palette="Blues_d")
# Out:
# C:\Users\Alexander\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:title={'center':'Распределение цены билета больше 100 по группе возраста'}, xlabel='group_age', ylabel='Fare'>

# %%
sns.barplot('group_age','Fare', data=data_eda[data_eda['Fare']<=100], palette="Blues_d")
plt.title('Распределение цены билета меньше 101 по группе возраста')
# Out:
# C:\Users\Alexander\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'Распределение цены билета меньше 101 по группе возраста')

# %%
plt.title('Какие билеты покупали люди с семьёй и без')
sns.kdeplot(data_eda['Fare'], hue = data_eda['bool_Parch'])
# Out:
# <AxesSubplot:title={'center':'Какие билеты покупали люди с семьёй и без'}, xlabel='Fare', ylabel='Density'>

# %%
surv_name = pd.DataFrame(data_eda[data_eda['Survived'] == 1]['first_name'].value_counts())
surv_name['name'] = surv_name.index
surv_name = surv_name.rename(columns = {'first_name':'survived'})
not_surv_name = pd.DataFrame(data_eda[data_eda['Survived'] == 0]['first_name'].value_counts())
not_surv_name['name'] = not_surv_name.index
name_l = not_surv_name.rename(columns={'first_name':'not_survived'}).merge(surv_name, how = 'outer')
name_l = name_l.fillna(0)
name_l['coef'] = name_l['survived'] / (name_l['survived'] + name_l['not_survived'])
name_l['quantity'] = name_l['survived'] + name_l['not_survived']

# %%
name_l.sort_values(by='coef', ascending = False).iloc[1085]
# Out:
# not_survived     0.0
# name            Haga
# survived         1.0
# coef             1.0
# quantity         1.0
# Name: 18945, dtype: object

# %%
name_l.sort_values(by='quantity', ascending = False)
# Out:
#        not_survived           name  survived      coef  quantity
# 0             656.0          Smith     506.0  0.435456    1162.0
# 1             547.0        Johnson     403.0  0.424211     950.0
# 2             432.0       Williams     301.0  0.410641     733.0
# 3             382.0          Jones     299.0  0.439060     681.0
# 4             377.0          Brown     288.0  0.433083     665.0
# ...             ...            ...       ...       ...       ...
# 13620           1.0  Schmiedeskamp       0.0  0.000000       1.0
# 13621           1.0        Jorstad       0.0  0.000000       1.0
# 13625           1.0           Orio       0.0  0.000000       1.0
# 13626           1.0       Belgarde       0.0  0.000000       1.0
# 21557           0.0     Szaflarski       1.0  1.000000       1.0
#
# [21558 rows x 5 columns]

# %%
surv_name = pd.DataFrame(data_eda[data_eda['Survived'] == 1]['last_name'].value_counts())
surv_name['name'] = surv_name.index
surv_name = surv_name.rename(columns = {'last_name':'survived'})
not_surv_name = pd.DataFrame(data_eda[data_eda['Survived'] == 0]['last_name'].value_counts())
not_surv_name['name'] = not_surv_name.index
name_l = not_surv_name.rename(columns={'last_name':'not_survived'}).merge(surv_name, how = 'outer')
name_l = name_l.fillna(0)
name_l['coef'] = name_l['survived'] / (name_l['survived'] + name_l['not_survived'])
name_l['quantity'] = name_l['survived'] + name_l['not_survived']

# %%
name_l.sort_values(by='coef', ascending = False).iloc[1085]
# Out:
# not_survived         0.0
# name            Georgina
# survived             2.0
# coef                 1.0
# quantity             2.0
# Name: 3199, dtype: object

# %%
name_l.sort_values(by='quantity', ascending = False)
# Out:
#       not_survived      name  survived      coef  quantity
# 1           1661.0     James     451.0  0.213542    2112.0
# 0           1671.0      John     416.0  0.199329    2087.0
# 2           1555.0    Robert     396.0  0.202973    1951.0
# 3           1328.0   Michael     357.0  0.211869    1685.0
# 4           1219.0   William     306.0  0.200656    1525.0
# ...            ...       ...       ...       ...       ...
# 3306           0.0   Assunta       1.0  1.000000       1.0
# 3307           0.0     Tuyet       1.0  1.000000       1.0
# 3308           0.0  Kimberli       1.0  1.000000       1.0
# 3309           0.0    Alisia       1.0  1.000000       1.0
# 3952           0.0      Aura       1.0  1.000000       1.0
#
# [3953 rows x 5 columns]

# %%
plt.figure(figsize=(12, 6))
plt.title('цены билетов в разных портах')
sns.kdeplot(data_eda['Fare'], hue = data_eda['Embarked'])
# Out:
# <AxesSubplot:title={'center':'цены билетов в разных портах'}, xlabel='Fare', ylabel='Density'>

# %%
plt.figure(figsize=(12, 6))
plt.title('цены билетов в разных портах')
sns.kdeplot(data_eda.loc[data_eda['Fare'] > 600, 'Fare'], hue = data_eda.loc[data_eda['Fare'] > 600, 'Embarked'])
# Out:
# <AxesSubplot:title={'center':'цены билетов в разных портах'}, xlabel='Fare', ylabel='Density'>

# %%
plt.figure(figsize=(12, 6))
plt.title('количество купленных билетов разных цен в разных классах')
sns.kdeplot(data_eda['Fare'], hue = data_eda['Pclass'])
# Out:
# <AxesSubplot:title={'center':'количество купленных билетов разных цен в разных классах'}, xlabel='Fare', ylabel='Density'>

# %%
plt.figure(figsize=(12, 6))
plt.title('количество купленных билетов разных цен больше 600 в разных классах')
sns.kdeplot(data_eda.loc[data_eda['Fare'] > 600, 'Fare'], hue = data_eda.loc[data_eda['Fare'] > 600, 'Pclass'])
# Out:
# <AxesSubplot:title={'center':'количество купленных билетов разных цен больше 600 в разных классах'}, xlabel='Fare', ylabel='Density'>

# %%
print('средняя цена билкта в порту S', data_eda.loc[data_eda['Embarked'] == 'S', 'Fare'].mean())
# Out:
# средняя цена билкта в порту S 33.20000777270393

# %%
print('средняя цена билкта в порту С', data_eda.loc[data_eda['Embarked'] == 'C', 'Fare'].mean())
# Out:
# средняя цена билкта в порту С 71.54907285366082

# %%
print('средняя цена билкта в порту Q', data_eda.loc[data_eda['Embarked'] == 'Q', 'Fare'].mean())
# Out:
# средняя цена билкта в порту Q 73.38514771048735

# %%
def z(x):
    return int(int(x) / 1000)
data_eda['num_of_cabin_thousands'] = data_eda['num_of_cabin'].dropna().apply(z)
sns.catplot('num_of_cabin_thousands', data = data_eda, hue = 'Survived', kind = 'count')
plt.title('влияние номера кабины на смертность')
# Out:
# C:\Users\Alexander\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'влияние номера кабины на смертность')

# %%
sns.kdeplot(data_eda['Parch'], hue = data_eda['Pclass'])
plt.title('Распределение коичества родствеников по классам')
# Out:
# Text(0.5, 1.0, 'Распределение коичества родствеников по классам')

# %%
plt.title('Распределение коичества родствеников > 5 по классам')
sns.kdeplot(data_eda.loc[data_eda['Parch'] > 5, 'Parch'], hue = data_eda.loc[data_eda['Parch'] > 5, 'Pclass'])
# Out:
# <AxesSubplot:title={'center':'Распределение коичества родствеников > 5 по классам'}, xlabel='Parch', ylabel='Density'>

# %%
plt.title('Распределение выживших и не выживших по цене и возрасту')
sns.scatterplot(x=data_eda['Age'], y=data_eda['Fare'], hue = data_eda['Survived'])
# Out:
# <AxesSubplot:title={'center':'Распределение выживших и не выживших по цене и возрасту'}, xlabel='Age', ylabel='Fare'>

# %% [markdown]
# **посмотрим на эту таблицу через другой метод**

# %%
plt.title('Выживаемость в зависимости от цены билета')
sns.kdeplot(data_eda['Fare'], hue = data_eda['Survived'])
# Out:
# <AxesSubplot:title={'center':'Выживаемость в зависимости от цены билета'}, xlabel='Fare', ylabel='Density'>

# %% [markdown]
# **можно выделить участок со 100 до 300, т.к. в нём очень много выживших**

# %%
plt.title('Выживаемость в зависимости от цены билета > 100')
sns.kdeplot(data_eda.loc[data_eda['Fare'] > 100, 'Fare'], \
            hue = data_eda.loc[data_eda['Fare'] > 100, 'Survived'])
# Out:
# <AxesSubplot:title={'center':'Выживаемость в зависимости от цены билета > 100'}, xlabel='Fare', ylabel='Density'>

# %%
plt.title('Выживаемость в зависимости от цены билета > 100 и < 300')
sns.kdeplot(data_eda.loc[(data_eda['Fare'] > 100) & (data_eda['Fare'] < 300), 'Fare'], \
            hue = data_eda.loc[(data_eda['Fare'] > 100) & (data_eda['Fare'] < 300), 'Survived'])
# Out:
# <AxesSubplot:title={'center':'Выживаемость в зависимости от цены билета > 100 и < 300'}, xlabel='Fare', ylabel='Density'>

# %% [markdown]
# **самая лучшая цена билета 250**

# %%
plt.title('Распределение цены билета по размеру семьи')
sns.scatterplot(y=data_eda['Fare'], x=data_eda['family_size'], hue=data_eda['Survived'])
# Out:
# <AxesSubplot:title={'center':'Распределение цены билета по размеру семьи'}, xlabel='family_size', ylabel='Fare'>

# %%
plt.title('Выживание людей до 18 лет')
sns.kdeplot(data_eda.loc[data_eda['Age'] < 18, 'Age'], hue = data_eda['Survived'])
# Out:
# <AxesSubplot:title={'center':'Выживание людей до 18 лет'}, xlabel='Age', ylabel='Density'>

# %%
plt.title('Выживание людей после 18 лет')
sns.kdeplot(data_eda.loc[data_eda['Age'] >= 18, 'Age'], hue = data_eda['Survived'])
# Out:
# <AxesSubplot:title={'center':'Выживание людей после 18 лет'}, xlabel='Age', ylabel='Density'>

# %% [markdown]
# # Summary

# %% [markdown]
# Больше всего ехало людей без родных
#
# Лучший вораст для выживания 41-43 года
#
# Большее кол-во людей не выжило
#
# Больше выжило девушек, чем парней
#
# Больше выжило людей из 1 класса
#
# Больше девушек было в 1 и 2 классах, а в 3 было больше парней
#
# Больше людей в соотношение выжило/не выжило выжило с 2 SibSp
#
# Лучшее количество родствеников на борту - 1
#
# Людей, чей билет с припиской PC, выжило больше в соотношении выжило/не выжило
#
# Женщин без родствеников выжило больше чем с родствениками
#
# Больше людей выживало в кабинах с буквами C и D
#
# Больше людей выживало, ехавших с порта C
#
# Чаще всего люди покупали дешёвые билеты
#
# Люди с детьми покупали билеты в более меньшем диапазоне
#
# 1085 имён имеет выживаемость 100
#
# 1085 фамилий имеет выживаемость 100%
#
# Самая популярная фамилия - James (2112 раз)
#
# Дешёвые билеты чаще покупали в порту S и 3 класс
#
# Дорогие билеты чаще покупали в порту C и 1 класс
#
# средняя цена билкта в порту S 33.18886150348626
#
# средняя цена билкта в порту С 71.47903456979319
#
# средняя цена билкта в порту Q 73.3129867256636
#
# номер кабины не влияет на выживание
#
# Самая лучшая цена билета 250
#
# Чем больше людей в семье, тем меньше средняя цена билета
#
# Дети 12-14 лет выживали чаще, чем не выживали
#
# Люди 64-75 лет выживали чаще, чем не выживали
#
# Самому старшему спасённому человеку +-85 лет

# %% [markdown]
# **Билет и человек с большими шансами на выживание**
# лет: 42
#
# пол: Женский
#
# класс: 1
#
# буква кабины: С
#
# порт посадки: С
#
# иметь имя и фамилию из этих таблиц:
#
# цена билета = +-250
#
# количество родствеников на борту: 0
#
# количество SibSp на борту: 2
#
# буквы в билете: PC

# %% [markdown]
# Контакт для связи в ds: BelyaevAlex
